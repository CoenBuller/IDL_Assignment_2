# %%
import numpy as np
import tensorflow as tf


# Percorsi ai file
X = np.load("dataset_75/images.npy")
y = np.load("dataset_75/labels.npy")

X = X.astype("float32") / 255.0

X = X[..., np.newaxis]

print(X.shape)  # es. (18000, 150, 150) o (18000, 75, 75)
print(y.shape)  # es. (18000, 2)
# Out:
# (18000, 75, 75, 1)
# (18000, 2)

# %%
label_range=30 #minutes the are togheter in the same class
number_of_classifiers=12*60//label_range

label=y[:,0]+y[:,1]/60

print(label[17999])
print(y[17999])
print(number_of_classifiers)
# Out:
# 11.983333333333333
# [11 59]
# 24

# %%
from sklearn.model_selection import train_test_split

X_traina, X_test, y_traina, y_test = train_test_split(X, label, test_size=0.1, random_state=42, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X_traina, y_traina, test_size=y_test.shape[0], random_state=42, shuffle=True)

print(X_test.shape)
print(X_val.shape)
print(X_train.shape)
print(X_train[0].shape)
# Out:
# (1800, 75, 75, 1)
# (1800, 75, 75, 1)
# (14400, 75, 75, 1)
# (75, 75, 1)

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from keras import layers, models, regularizers
from keras.optimizers import AdamW
from keras.callbacks import ReduceLROnPlateau

# %%
class PeriodicOutput(layers.Layer):
    def call(self, inputs):
        return (tf.math.sin(inputs) + 1) * 6  

model_base = models.Sequential([
    keras.layers.Conv2D(32, (5,5), padding="same", input_shape=X_train[0].shape),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D(),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(64, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(2,2),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(128, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(2,2),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(256, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    #keras.layers.AveragePooling2D(2,2),
    #keras.layers.Dropout(0.3),    

    keras.layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.3),
    keras.layers.Dense(1),
    PeriodicOutput()
])
# Out:
# /vol/home/s4949404/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
def custom_accuracy(y_true, y_pred):
    diff = tf.minimum(tf.abs(y_true - y_pred), tf.abs(12 - tf.abs(y_true - y_pred)))
    return tf.reduce_mean(tf.cast(diff < 0.5, tf.float32))

model_base.compile(
    optimizer=AdamW(learning_rate=1e-4, weight_decay=5e-5),
    loss="mse",
    metrics=[custom_accuracy]
)

# %%
# Reduce LR when validation loss stops improving
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=5, min_lr=1e-7
)

checkpoint = keras.callbacks.ModelCheckpoint(
    "best_model.keras",
    save_best_only=True
)

early_stopping=keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True
)

# %%
history_base = model_base.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[lr_scheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - custom_accuracy: 0.0827 - loss: 10.3171 - val_custom_accuracy: 0.0857 - val_loss: 17.6373 - learning_rate: 1.0000e-04
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0832 - loss: 8.5117 - val_custom_accuracy: 0.0897 - val_loss: 44.2781 - learning_rate: 1.0000e-04
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0832 - loss: 7.7169 - val_custom_accuracy: 0.0835 - val_loss: 20.6634 - learning_rate: 1.0000e-04
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0836 - loss: 7.1997 - val_custom_accuracy: 0.0808 - val_loss: 39.8434 - learning_rate: 1.0000e-04
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0839 - loss: 6.6549 - val_custom_accuracy: 0.0821 - val_loss: 31.4069 - learning_rate: 1.0000e-04
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0836 - loss: 6.1740 - val_custom_accuracy: 0.0838 - val_loss: 11.8011 - learning_rate: 1.0000e-04
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0839 - loss: 5.6291 - val_custom_accuracy: 0.0876 - val_loss: 23.2502 - learning_rate: 1.0000e-04
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0845 - loss: 5.1360 - val_custom_accuracy: 0.0853 - val_loss: 6.8469 - learning_rate: 1.0000e-04
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0848 - loss: 4.6470 - val_custom_accuracy: 0.0844 - val_loss: 20.2884 - learning_rate: 1.0000e-04
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0849 - loss: 4.2462 - val_custom_accuracy: 0.0842 - val_loss: 10.0929 - learning_rate: 1.0000e-04
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0851 - loss: 3.8481 - val_custom_accuracy: 0.0811 - val_loss: 31.6880 - learning_rate: 1.0000e-04
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0852 - loss: 3.4996 - val_custom_accuracy: 0.0808 - val_loss: 20.0520 - learning_rate: 1.0000e-04
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0857 - loss: 3.2033 - val_custom_accuracy: 0.0881 - val_loss: 5.0288 - learning_rate: 1.0000e-04
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0857 - loss: 2.9229 - val_custom_accuracy: 0.0828 - val_loss: 14.0050 - learning_rate: 1.0000e-04
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0853 - loss: 2.6822 - val_custom_accuracy: 0.0828 - val_loss: 12.6019 - learning_rate: 1.0000e-04
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0858 - loss: 2.4571 - val_custom_accuracy: 0.0838 - val_loss: 5.6724 - learning_rate: 1.0000e-04
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0855 - loss: 2.2331 - val_custom_accuracy: 0.0863 - val_loss: 6.9080 - learning_rate: 1.0000e-04
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0858 - loss: 2.0773 - val_custom_accuracy: 0.0819 - val_loss: 13.4893 - learning_rate: 1.0000e-04
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0873 - loss: 1.6718 - val_custom_accuracy: 0.0852 - val_loss: 4.9543 - learning_rate: 5.0000e-05
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0869 - loss: 1.5740 - val_custom_accuracy: 0.0830 - val_loss: 8.7508 - learning_rate: 5.0000e-05
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0869 - loss: 1.5015 - val_custom_accuracy: 0.0868 - val_loss: 2.7726 - learning_rate: 5.0000e-05
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0868 - loss: 1.3964 - val_custom_accuracy: 0.0883 - val_loss: 5.8866 - learning_rate: 5.0000e-05
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0873 - loss: 1.3529 - val_custom_accuracy: 0.0874 - val_loss: 6.1451 - learning_rate: 5.0000e-05
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0872 - loss: 1.2528 - val_custom_accuracy: 0.0868 - val_loss: 17.8728 - learning_rate: 5.0000e-05
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0877 - loss: 1.2594 - val_custom_accuracy: 0.0861 - val_loss: 4.7235 - learning_rate: 5.0000e-05
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0877 - loss: 1.2072 - val_custom_accuracy: 0.0883 - val_loss: 9.2459 - learning_rate: 5.0000e-05
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0887 - loss: 0.9995 - val_custom_accuracy: 0.0896 - val_loss: 2.4765 - learning_rate: 2.5000e-05
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0887 - loss: 0.9750 - val_custom_accuracy: 0.0881 - val_loss: 2.7748 - learning_rate: 2.5000e-05
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0880 - loss: 0.9456 - val_custom_accuracy: 0.0870 - val_loss: 4.2269 - learning_rate: 2.5000e-05
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0881 - loss: 0.9225 - val_custom_accuracy: 0.0880 - val_loss: 4.5800 - learning_rate: 2.5000e-05
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0883 - loss: 0.9277 - val_custom_accuracy: 0.0864 - val_loss: 3.1935 - learning_rate: 2.5000e-05
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0878 - loss: 0.8782 - val_custom_accuracy: 0.0871 - val_loss: 4.0573 - learning_rate: 2.5000e-05
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0883 - loss: 0.8210 - val_custom_accuracy: 0.0905 - val_loss: 1.8249 - learning_rate: 1.2500e-05
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0884 - loss: 0.8080 - val_custom_accuracy: 0.0824 - val_loss: 4.3381 - learning_rate: 1.2500e-05
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0888 - loss: 0.8086 - val_custom_accuracy: 0.0892 - val_loss: 1.7071 - learning_rate: 1.2500e-05
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0886 - loss: 0.7859 - val_custom_accuracy: 0.0906 - val_loss: 1.6604 - learning_rate: 1.2500e-05
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0883 - loss: 0.7642 - val_custom_accuracy: 0.0896 - val_loss: 2.1858 - learning_rate: 1.2500e-05
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0889 - loss: 0.7726 - val_custom_accuracy: 0.0907 - val_loss: 1.6065 - learning_rate: 1.2500e-05
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0889 - loss: 0.7456 - val_custom_accuracy: 0.0887 - val_loss: 1.9688 - learning_rate: 1.2500e-05
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0888 - loss: 0.7475 - val_custom_accuracy: 0.0874 - val_loss: 2.1093 - learning_rate: 1.2500e-05
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0891 - loss: 0.7265 - val_custom_accuracy: 0.0909 - val_loss: 1.6554 - learning_rate: 1.2500e-05
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0888 - loss: 0.7255 - val_custom_accuracy: 0.0904 - val_loss: 1.6332 - learning_rate: 1.2500e-05
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0887 - loss: 0.7040 - val_custom_accuracy: 0.0857 - val_loss: 3.1202 - learning_rate: 1.2500e-05
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0892 - loss: 0.6950 - val_custom_accuracy: 0.0902 - val_loss: 1.6884 - learning_rate: 6.2500e-06
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0886 - loss: 0.6837 - val_custom_accuracy: 0.0914 - val_loss: 1.5413 - learning_rate: 6.2500e-06
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0887 - loss: 0.6617 - val_custom_accuracy: 0.0892 - val_loss: 1.7278 - learning_rate: 6.2500e-06
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0889 - loss: 0.6591 - val_custom_accuracy: 0.0909 - val_loss: 1.5432 - learning_rate: 6.2500e-06
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0889 - loss: 0.6526 - val_custom_accuracy: 0.0897 - val_loss: 1.5873 - learning_rate: 6.2500e-06
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0893 - loss: 0.6626 - val_custom_accuracy: 0.0871 - val_loss: 2.0211 - learning_rate: 6.2500e-06
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0888 - loss: 0.6519 - val_custom_accuracy: 0.0907 - val_loss: 1.6823 - learning_rate: 6.2500e-06
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0894 - loss: 0.6443 - val_custom_accuracy: 0.0919 - val_loss: 1.5153 - learning_rate: 3.1250e-06
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.6361 - val_custom_accuracy: 0.0909 - val_loss: 1.6269 - learning_rate: 3.1250e-06
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0893 - loss: 0.6502 - val_custom_accuracy: 0.0916 - val_loss: 1.5225 - learning_rate: 3.1250e-06
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0894 - loss: 0.6302 - val_custom_accuracy: 0.0914 - val_loss: 1.4743 - learning_rate: 3.1250e-06
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0891 - loss: 0.6294 - val_custom_accuracy: 0.0915 - val_loss: 1.6239 - learning_rate: 3.1250e-06
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0896 - loss: 0.6328 - val_custom_accuracy: 0.0921 - val_loss: 1.4794 - learning_rate: 3.1250e-06
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0891 - loss: 0.6451 - val_custom_accuracy: 0.0901 - val_loss: 1.5745 - learning_rate: 3.1250e-06
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0891 - loss: 0.6200 - val_custom_accuracy: 0.0889 - val_loss: 1.7861 - learning_rate: 3.1250e-06
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0889 - loss: 0.6208 - val_custom_accuracy: 0.0913 - val_loss: 1.4722 - learning_rate: 3.1250e-06
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.6159 - val_custom_accuracy: 0.0925 - val_loss: 1.7246 - learning_rate: 3.1250e-06
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0899 - loss: 0.6064 - val_custom_accuracy: 0.0920 - val_loss: 1.4795 - learning_rate: 3.1250e-06
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0886 - loss: 0.6102 - val_custom_accuracy: 0.0930 - val_loss: 1.4438 - learning_rate: 3.1250e-06
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0885 - loss: 0.6135 - val_custom_accuracy: 0.0908 - val_loss: 1.5161 - learning_rate: 3.1250e-06
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0894 - loss: 0.6009 - val_custom_accuracy: 0.0922 - val_loss: 1.4704 - learning_rate: 3.1250e-06
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0894 - loss: 0.6069 - val_custom_accuracy: 0.0896 - val_loss: 1.5097 - learning_rate: 3.1250e-06
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0890 - loss: 0.5954 - val_custom_accuracy: 0.0916 - val_loss: 1.4878 - learning_rate: 3.1250e-06
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.6185 - val_custom_accuracy: 0.0922 - val_loss: 1.5313 - learning_rate: 3.1250e-06
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.5992 - val_custom_accuracy: 0.0907 - val_loss: 1.4944 - learning_rate: 1.5625e-06
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0897 - loss: 0.5938 - val_custom_accuracy: 0.0913 - val_loss: 1.5086 - learning_rate: 1.5625e-06
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0897 - loss: 0.6108 - val_custom_accuracy: 0.0919 - val_loss: 1.4436 - learning_rate: 1.5625e-06
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0898 - loss: 0.5992 - val_custom_accuracy: 0.0912 - val_loss: 1.4753 - learning_rate: 1.5625e-06
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0891 - loss: 0.5860 - val_custom_accuracy: 0.0919 - val_loss: 1.4917 - learning_rate: 1.5625e-06
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.6073 - val_custom_accuracy: 0.0912 - val_loss: 1.4667 - learning_rate: 1.5625e-06
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0899 - loss: 0.5826 - val_custom_accuracy: 0.0917 - val_loss: 1.4872 - learning_rate: 1.5625e-06
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0896 - loss: 0.5957 - val_custom_accuracy: 0.0915 - val_loss: 1.4640 - learning_rate: 1.5625e-06
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0899 - loss: 0.5799 - val_custom_accuracy: 0.0923 - val_loss: 1.4351 - learning_rate: 7.8125e-07
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0900 - loss: 0.5871 - val_custom_accuracy: 0.0917 - val_loss: 1.4568 - learning_rate: 7.8125e-07
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0899 - loss: 0.5707 - val_custom_accuracy: 0.0921 - val_loss: 1.4502 - learning_rate: 7.8125e-07
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.5758 - val_custom_accuracy: 0.0922 - val_loss: 1.4397 - learning_rate: 7.8125e-07
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0896 - loss: 0.5924 - val_custom_accuracy: 0.0905 - val_loss: 1.4972 - learning_rate: 7.8125e-07
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0895 - loss: 0.5766 - val_custom_accuracy: 0.0915 - val_loss: 1.4513 - learning_rate: 7.8125e-07
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0898 - loss: 0.5823 - val_custom_accuracy: 0.0919 - val_loss: 1.4448 - learning_rate: 3.9062e-07
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0897 - loss: 0.5849 - val_custom_accuracy: 0.0924 - val_loss: 1.4366 - learning_rate: 3.9062e-07
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0899 - loss: 0.5774 - val_custom_accuracy: 0.0917 - val_loss: 1.4457 - learning_rate: 3.9062e-07
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - custom_accuracy: 0.0896 - loss: 0.5823 - val_custom_accuracy: 0.0918 - val_loss: 1.4412 - learning_rate: 3.9062e-07
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - custom_accuracy: 0.0897 - loss: 0.5755 - val_custom_accuracy: 0.0918 - val_loss: 1.4427 - learning_rate: 3.9062e-07

# %%
# Carichiamo il modello salvato con i pesi migliori
best = keras.models.load_model("best_model.keras")

# Valutiamo sul test set
test_loss, test_acc = best.evaluate(X_train, y_train)
print(f"Loss sul train set: {test_loss:.4f}")
print(f"Accuratezza sul train set: {test_acc:.4f}")

# Valutiamo sul test set
test_loss, test_acc = best.evaluate(X_test, y_test)
print(f"Loss sul test set: {test_loss:.4f}")
print(f"Accuratezza sul test set: {test_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:733, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732 try:
# --> 733     instance = cls.from_config(inner_config)
#     734 except TypeError as e:
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/models/sequential.py:371, in Sequential.from_config(cls, config, custom_objects)
#     370 else:
# --> 371     layer = serialization_lib.deserialize_keras_object(
#     372         layer_config,
#     373         custom_objects=custom_objects,
#     374     )
#     375 model.add(layer)
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:709, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     707         return obj
# --> 709 cls = _retrieve_class_or_fn(
#     710     class_name,
#     711     registered_name,
#     712     module,
#     713     obj_type="class",
#     714     full_config=config,
#     715     custom_objects=custom_objects,
#     716 )
#     718 if isinstance(cls, types.FunctionType):
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:836, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     830             raise TypeError(
#     831                 f"Could not deserialize {obj_type} '{name}' because "
#     832                 f"its parent module {module} cannot be imported. "
#     833                 f"Full object config: {full_config}"
#     834             )
# --> 836 raise TypeError(
#     837     f"Could not locate {obj_type} '{name}'. "
#     838     "Make sure custom classes are decorated with "
#     839     "`@keras.saving.register_keras_serializable()`. "
#     840     f"Full object config: {full_config}"
#     841 )
#
# TypeError: Could not locate class 'PeriodicOutput'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': None, 'class_name': 'PeriodicOutput', 'config': {'name': 'periodic_output_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}}, 'registered_name': 'PeriodicOutput', 'build_config': {'input_shape': [None, 1]}}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Carichiamo il modello salvato con i pesi migliori
# ----> 2 best = keras.models.load_model("best_model.keras")
#       4 # Valutiamo sul test set
#       5 test_loss, test_acc = best.evaluate(X_train, y_train)
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     186         is_keras_zip = True
#     188 if is_keras_zip or is_keras_dir or is_hf:
# --> 189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:365, in load_model(filepath, custom_objects, compile, safe_mode)
#     360     raise ValueError(
#     361         "Invalid filename: expected a `.keras` extension. "
#     362         f"Received: filepath={filepath}"
#     363     )
#     364 with open(filepath, "rb") as f:
# --> 365     return _load_model_from_fileobj(
#     366         f, custom_objects, compile, safe_mode
#     367     )
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:442, in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     439 with zf.open(_CONFIG_FILENAME, "r") as f:
#     440     config_json = f.read()
# --> 442 model = _model_from_config(
#     443     config_json, custom_objects, compile, safe_mode
#     444 )
#     446 all_filenames = zf.namelist()
#     447 extract_dir = None
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:431, in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     429 # Construct the model from the configuration file in the archive.
#     430 with ObjectSharingScope():
# --> 431     model = deserialize_keras_object(
#     432         config_dict, custom_objects, safe_mode=safe_mode
#     433     )
#     434 return model
#
# File ~/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:735, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     733     instance = cls.from_config(inner_config)
#     734 except TypeError as e:
# --> 735     raise TypeError(
#     736         f"{cls} could not be deserialized properly. Please"
#     737         " ensure that components that are Python object"
#     738         " instances (layers, models, etc.) returned by"
#     739         " `get_config()` are explicitly deserialized in the"
#     740         " model's `from_config()` method."
#     741         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     742     )
#     743 build_config = config.get("build_config", None)
#     744 if build_config and not instance.built:
#
# TypeError: <class 'keras.src.models.sequential.Sequential'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras', 'class_name': 'Sequential', 'config': {'name': 'sequential_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 75, 75, 1], 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_layer_1'}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d_4', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 32, 'kernel_size': [5, 5], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 75, 75, 1]}}, {'module': 'keras.layers', 'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization_4', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False}, 'registered_name': None, 'build_config': {'input_shape': [None, 75, 75, 32]}}, {'module': 'keras.layers', 'class_name': 'ReLU', 'config': {'name': 're_lu_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}, 'max_value': None, 'negative_slope': 0.0, 'threshold': 0.0}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}, 'pool_size': [2, 2], 'padding': 'valid', 'strides': [2, 2], 'data_format': 'channels_last'}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d_5', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}, 'filters': 64, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_sha ...
#
# Exception encountered: Could not locate class 'PeriodicOutput'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': None, 'class_name': 'PeriodicOutput', 'config': {'name': 'periodic_output_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 131698008186160}}, 'registered_name': 'PeriodicOutput', 'build_config': {'input_shape': [None, 1]}}

# %%
y_pred = model_base.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_classes)
ConfusionMatrixDisplay(cm).plot()

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history_base.history["accuracy"], label="Train")
plt.plot(history_base.history["val_accuracy"], label="Validation")
plt.title("Accuratezza")
plt.xlabel("Epoca")
plt.ylabel("Accuracy")
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history_base.history["loss"], label="Train")
plt.plot(history_base.history["val_loss"], label="Validation")
plt.title("Loss")
plt.xlabel("Epoca")
plt.ylabel("Loss")
plt.legend()

plt.show()
