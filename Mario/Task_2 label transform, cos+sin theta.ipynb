# %%
import numpy as np
import tensorflow as tf


# Percorsi ai file
X = np.load("dataset_75/images.npy")
y = np.load("dataset_75/labels.npy")

X = X.astype("float32") / 255.0

X = X[..., np.newaxis]

print(X.shape)  # es. (18000, 150, 150) o (18000, 75, 75)
print(y.shape)  # es. (18000, 2)
# Out:
# (18000, 75, 75, 1)
# (18000, 2)

# %%
label_range=30 #minutes the are togheter in the same class
number_of_classifiers=12*60//label_range

hours_decimal=y[:,0]+y[:,1]/60
hours_normalized=hours_decimal/12
hours_angolized=hours_normalized*2*np.pi
labels=np.column_stack((np.cos(hours_angolized), np.sin(hours_angolized)))

print(labels[10999])
print(y[10999])
print(number_of_classifiers)
# Out:
# [-0.77162458 -0.63607822]
# [ 7 19]
# 24

# %%
from sklearn.model_selection import train_test_split

X_traina, X_test, y_traina, y_test = train_test_split(X, labels, test_size=0.1, random_state=42, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X_traina, y_traina, test_size=y_test.shape[0], random_state=42, shuffle=True)

print(y_test.shape)
print(y_val.shape)
print(y_train.shape)
print(y_train[0].shape)
# Out:
# (1800, 2)
# (1800, 2)
# (14400, 2)
# (2,)

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from keras import layers, models, regularizers
from keras.optimizers import AdamW
from keras.callbacks import ReduceLROnPlateau

# %%
class CosSin(layers.Layer):
    def call(self, inputs):
        return tf.math.l2_normalize(inputs, axis=-1)

model_base = models.Sequential([
    keras.layers.Conv2D(32, (5,5), padding="same", input_shape=X_train[0].shape),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D(),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(64, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(2,2),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(128, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(2,2),
    #keras.layers.Dropout(0.3),

    keras.layers.Conv2D(256, (3,3), padding="same", activation="relu"),
    keras.layers.BatchNormalization(),
    #keras.layers.AveragePooling2D(2,2),
    keras.layers.Dropout(0.3),    

    keras.layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    #keras.layers.Dropout(0.3), 
    layers.Dense(64, activation="relu" ),
    
    layers.Dropout(0.3),
    keras.layers.Dense(2),
    CosSin()
])

# %%
def angular_mse(y_true, y_pred):
    # sicurezza: normalizza su cerchio
    y_true = tf.math.l2_normalize(y_true, axis=-1)
    y_pred = tf.math.l2_normalize(y_pred, axis=-1)
    th_t = tf.atan2(y_true[...,1], y_true[...,0])  # atan2(sin, cos)
    th_p = tf.atan2(y_pred[...,1], y_pred[...,0])
    d   = tf.atan2(tf.sin(th_p - th_t), tf.cos(th_p - th_t))  # wrap in (−π, π]
    return tf.reduce_mean(tf.square(d)) 


def angular_mae_minutes(y_true, y_pred):
    y_true = tf.math.l2_normalize(y_true, axis=-1)
    y_pred = tf.math.l2_normalize(y_pred, axis=-1)
    th_t = tf.atan2(y_true[...,1], y_true[...,0])
    th_p = tf.atan2(y_pred[...,1], y_pred[...,0])
    d   = tf.atan2(tf.sin(th_p - th_t), tf.cos(th_p - th_t))
    err_min = tf.abs(d) * (12.*60.) / (2.*np.pi)       # minuti su quadrante 12h
    return tf.reduce_mean(err_min)

model_base.compile(
    optimizer=AdamW(learning_rate=1e-3, weight_decay=5e-5),
    loss=angular_mse,
    metrics=[angular_mae_minutes]
)

# %%
# Reduce LR when validation loss stops improving
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=5, min_lr=1e-7
)

checkpoint = keras.callbacks.ModelCheckpoint(
    "best_model.keras",
    save_best_only=True
)

early_stopping=keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True
)

# %%
history_base = model_base.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[lr_scheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - angular_mae_minutes: 178.2703 - loss: 3.2323 - val_angular_mae_minutes: 179.2029 - val_loss: 3.2624 - learning_rate: 0.0010
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 178.3132 - loss: 3.2619 - val_angular_mae_minutes: 177.1546 - val_loss: 3.2096 - learning_rate: 0.0010
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 174.2678 - loss: 3.1256 - val_angular_mae_minutes: 178.9549 - val_loss: 3.2535 - learning_rate: 0.0010
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 167.5469 - loss: 2.9415 - val_angular_mae_minutes: 180.5365 - val_loss: 3.3202 - learning_rate: 0.0010
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 163.3818 - loss: 2.8280 - val_angular_mae_minutes: 180.1365 - val_loss: 3.3067 - learning_rate: 0.0010
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 148.7152 - loss: 2.4359 - val_angular_mae_minutes: 180.2758 - val_loss: 3.3028 - learning_rate: 0.0010
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 126.3007 - loss: 1.8510 - val_angular_mae_minutes: 164.0049 - val_loss: 2.8393 - learning_rate: 0.0010
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 114.2197 - loss: 1.5471 - val_angular_mae_minutes: 184.1315 - val_loss: 3.4027 - learning_rate: 0.0010
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 103.8969 - loss: 1.2855 - val_angular_mae_minutes: 198.2847 - val_loss: 3.7910 - learning_rate: 0.0010
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 98.3302 - loss: 1.1654 - val_angular_mae_minutes: 180.4077 - val_loss: 3.3070 - learning_rate: 0.0010
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 93.3355 - loss: 1.0531 - val_angular_mae_minutes: 139.6370 - val_loss: 2.1701 - learning_rate: 0.0010
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 78.2824 - loss: 0.7477 - val_angular_mae_minutes: 181.6512 - val_loss: 3.3341 - learning_rate: 0.0010
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 78.6827 - loss: 0.7848 - val_angular_mae_minutes: 178.7868 - val_loss: 3.2776 - learning_rate: 0.0010
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 61.7753 - loss: 0.4897 - val_angular_mae_minutes: 131.3648 - val_loss: 2.0164 - learning_rate: 0.0010
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 50.9029 - loss: 0.3521 - val_angular_mae_minutes: 167.7632 - val_loss: 2.9825 - learning_rate: 0.0010
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 53.4081 - loss: 0.3969 - val_angular_mae_minutes: 186.8887 - val_loss: 3.5123 - learning_rate: 0.0010
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 41.5282 - loss: 0.2402 - val_angular_mae_minutes: 48.7915 - val_loss: 0.3477 - learning_rate: 0.0010
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 34.9783 - loss: 0.1683 - val_angular_mae_minutes: 116.6059 - val_loss: 1.6627 - learning_rate: 0.0010
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 37.2265 - loss: 0.2054 - val_angular_mae_minutes: 52.9687 - val_loss: 0.3746 - learning_rate: 0.0010
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 34.5156 - loss: 0.1767 - val_angular_mae_minutes: 185.6768 - val_loss: 3.4068 - learning_rate: 0.0010
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 31.1166 - loss: 0.1400 - val_angular_mae_minutes: 199.3199 - val_loss: 3.8477 - learning_rate: 0.0010
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 30.6506 - loss: 0.1402 - val_angular_mae_minutes: 75.4011 - val_loss: 0.9627 - learning_rate: 0.0010
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 27.3933 - loss: 0.1079 - val_angular_mae_minutes: 154.4533 - val_loss: 2.5904 - learning_rate: 5.0000e-04
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 27.0671 - loss: 0.1078 - val_angular_mae_minutes: 29.2501 - val_loss: 0.1271 - learning_rate: 5.0000e-04
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 24.7421 - loss: 0.0870 - val_angular_mae_minutes: 189.3265 - val_loss: 3.5662 - learning_rate: 5.0000e-04
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 26.2229 - loss: 0.1008 - val_angular_mae_minutes: 63.6623 - val_loss: 0.6243 - learning_rate: 5.0000e-04
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 22.9916 - loss: 0.0736 - val_angular_mae_minutes: 63.9585 - val_loss: 0.6972 - learning_rate: 5.0000e-04
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 22.0494 - loss: 0.0674 - val_angular_mae_minutes: 23.8494 - val_loss: 0.1072 - learning_rate: 5.0000e-04
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 21.2478 - loss: 0.0624 - val_angular_mae_minutes: 61.5405 - val_loss: 0.5647 - learning_rate: 5.0000e-04
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 21.6263 - loss: 0.0651 - val_angular_mae_minutes: 113.3345 - val_loss: 1.7383 - learning_rate: 5.0000e-04
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 29.3363 - loss: 0.1490 - val_angular_mae_minutes: 180.3368 - val_loss: 3.3049 - learning_rate: 5.0000e-04
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 37.4378 - loss: 0.2367 - val_angular_mae_minutes: 186.1351 - val_loss: 3.4542 - learning_rate: 5.0000e-04
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 25.7730 - loss: 0.0937 - val_angular_mae_minutes: 24.5454 - val_loss: 0.1085 - learning_rate: 5.0000e-04
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 22.7473 - loss: 0.0714 - val_angular_mae_minutes: 41.0703 - val_loss: 0.2590 - learning_rate: 2.5000e-04
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 21.5148 - loss: 0.0607 - val_angular_mae_minutes: 37.9609 - val_loss: 0.2382 - learning_rate: 2.5000e-04
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 20.8478 - loss: 0.0569 - val_angular_mae_minutes: 17.7938 - val_loss: 0.0590 - learning_rate: 2.5000e-04
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 20.1134 - loss: 0.0529 - val_angular_mae_minutes: 21.9299 - val_loss: 0.1106 - learning_rate: 2.5000e-04
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 20.2562 - loss: 0.0540 - val_angular_mae_minutes: 20.7912 - val_loss: 0.0693 - learning_rate: 2.5000e-04
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 19.3664 - loss: 0.0498 - val_angular_mae_minutes: 21.8986 - val_loss: 0.1172 - learning_rate: 2.5000e-04
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 19.0118 - loss: 0.0468 - val_angular_mae_minutes: 13.8511 - val_loss: 0.0278 - learning_rate: 2.5000e-04
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 18.5531 - loss: 0.0442 - val_angular_mae_minutes: 32.7437 - val_loss: 0.1777 - learning_rate: 2.5000e-04
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 19.3166 - loss: 0.0513 - val_angular_mae_minutes: 23.5125 - val_loss: 0.1288 - learning_rate: 2.5000e-04
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 18.7244 - loss: 0.0475 - val_angular_mae_minutes: 69.9427 - val_loss: 0.7614 - learning_rate: 2.5000e-04
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 19.7418 - loss: 0.0551 - val_angular_mae_minutes: 15.2986 - val_loss: 0.0508 - learning_rate: 2.5000e-04
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 18.2806 - loss: 0.0442 - val_angular_mae_minutes: 59.7893 - val_loss: 0.6668 - learning_rate: 2.5000e-04
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 18.1388 - loss: 0.0434 - val_angular_mae_minutes: 44.4466 - val_loss: 0.3773 - learning_rate: 1.2500e-04
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 17.3400 - loss: 0.0380 - val_angular_mae_minutes: 10.5014 - val_loss: 0.0166 - learning_rate: 1.2500e-04
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 17.1356 - loss: 0.0368 - val_angular_mae_minutes: 15.9934 - val_loss: 0.0555 - learning_rate: 1.2500e-04
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 17.4237 - loss: 0.0384 - val_angular_mae_minutes: 20.0479 - val_loss: 0.0957 - learning_rate: 1.2500e-04
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 18.7769 - loss: 0.0537 - val_angular_mae_minutes: 18.4466 - val_loss: 0.0726 - learning_rate: 1.2500e-04
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 17.3076 - loss: 0.0401 - val_angular_mae_minutes: 12.0563 - val_loss: 0.0262 - learning_rate: 1.2500e-04
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.7670 - loss: 0.0351 - val_angular_mae_minutes: 9.8834 - val_loss: 0.0151 - learning_rate: 1.2500e-04
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.4402 - loss: 0.0340 - val_angular_mae_minutes: 31.6608 - val_loss: 0.1859 - learning_rate: 1.2500e-04
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.3860 - loss: 0.0342 - val_angular_mae_minutes: 11.5796 - val_loss: 0.0226 - learning_rate: 1.2500e-04
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.2503 - loss: 0.0331 - val_angular_mae_minutes: 11.3549 - val_loss: 0.0213 - learning_rate: 1.2500e-04
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.0564 - loss: 0.0319 - val_angular_mae_minutes: 16.0124 - val_loss: 0.0494 - learning_rate: 1.2500e-04
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.9630 - loss: 0.0320 - val_angular_mae_minutes: 10.4336 - val_loss: 0.0169 - learning_rate: 1.2500e-04
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.7996 - loss: 0.0314 - val_angular_mae_minutes: 9.2962 - val_loss: 0.0142 - learning_rate: 6.2500e-05
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.7911 - loss: 0.0317 - val_angular_mae_minutes: 10.6870 - val_loss: 0.0182 - learning_rate: 6.2500e-05
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.5485 - loss: 0.0302 - val_angular_mae_minutes: 8.8174 - val_loss: 0.0123 - learning_rate: 6.2500e-05
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.5861 - loss: 0.0304 - val_angular_mae_minutes: 9.4740 - val_loss: 0.0132 - learning_rate: 6.2500e-05
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.5575 - loss: 0.0307 - val_angular_mae_minutes: 139.5014 - val_loss: 2.2461 - learning_rate: 6.2500e-05
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 16.2593 - loss: 0.0367 - val_angular_mae_minutes: 37.7038 - val_loss: 0.2863 - learning_rate: 6.2500e-05
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.7390 - loss: 0.0309 - val_angular_mae_minutes: 15.9434 - val_loss: 0.0549 - learning_rate: 6.2500e-05
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.2380 - loss: 0.0289 - val_angular_mae_minutes: 13.1572 - val_loss: 0.0312 - learning_rate: 6.2500e-05
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.3612 - loss: 0.0297 - val_angular_mae_minutes: 9.6837 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.2190 - loss: 0.0294 - val_angular_mae_minutes: 8.8834 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0773 - loss: 0.0282 - val_angular_mae_minutes: 8.6789 - val_loss: 0.0110 - learning_rate: 3.1250e-05
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.1568 - loss: 0.0287 - val_angular_mae_minutes: 9.3094 - val_loss: 0.0135 - learning_rate: 3.1250e-05
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.1530 - loss: 0.0289 - val_angular_mae_minutes: 19.4492 - val_loss: 0.0671 - learning_rate: 3.1250e-05
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0880 - loss: 0.0283 - val_angular_mae_minutes: 8.4634 - val_loss: 0.0108 - learning_rate: 3.1250e-05
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0881 - loss: 0.0281 - val_angular_mae_minutes: 9.4819 - val_loss: 0.0150 - learning_rate: 3.1250e-05
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.1899 - loss: 0.0288 - val_angular_mae_minutes: 8.4946 - val_loss: 0.0116 - learning_rate: 3.1250e-05
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0273 - loss: 0.0281 - val_angular_mae_minutes: 8.3092 - val_loss: 0.0113 - learning_rate: 3.1250e-05
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.9152 - loss: 0.0277 - val_angular_mae_minutes: 8.5059 - val_loss: 0.0108 - learning_rate: 3.1250e-05
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.1488 - loss: 0.0295 - val_angular_mae_minutes: 12.1032 - val_loss: 0.0324 - learning_rate: 3.1250e-05
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0299 - loss: 0.0281 - val_angular_mae_minutes: 8.2143 - val_loss: 0.0106 - learning_rate: 1.5625e-05
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.8386 - loss: 0.0274 - val_angular_mae_minutes: 9.8208 - val_loss: 0.0178 - learning_rate: 1.5625e-05
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 15.0132 - loss: 0.0282 - val_angular_mae_minutes: 9.3380 - val_loss: 0.0129 - learning_rate: 1.5625e-05
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.7120 - loss: 0.0268 - val_angular_mae_minutes: 8.1544 - val_loss: 0.0102 - learning_rate: 1.5625e-05
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.8879 - loss: 0.0275 - val_angular_mae_minutes: 8.1249 - val_loss: 0.0105 - learning_rate: 1.5625e-05
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.8744 - loss: 0.0277 - val_angular_mae_minutes: 11.3096 - val_loss: 0.0273 - learning_rate: 1.5625e-05
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.7430 - loss: 0.0269 - val_angular_mae_minutes: 7.9582 - val_loss: 0.0097 - learning_rate: 1.5625e-05
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.7568 - loss: 0.0271 - val_angular_mae_minutes: 8.0957 - val_loss: 0.0105 - learning_rate: 1.5625e-05
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.7998 - loss: 0.0273 - val_angular_mae_minutes: 8.2925 - val_loss: 0.0113 - learning_rate: 1.5625e-05
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.6872 - loss: 0.0267 - val_angular_mae_minutes: 10.0018 - val_loss: 0.0182 - learning_rate: 1.5625e-05
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.5474 - loss: 0.0263 - val_angular_mae_minutes: 9.1304 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.5618 - loss: 0.0263 - val_angular_mae_minutes: 8.1018 - val_loss: 0.0107 - learning_rate: 1.5625e-05
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.6243 - loss: 0.0265 - val_angular_mae_minutes: 8.1460 - val_loss: 0.0107 - learning_rate: 7.8125e-06
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.5788 - loss: 0.0265 - val_angular_mae_minutes: 8.6653 - val_loss: 0.0114 - learning_rate: 7.8125e-06
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.5052 - loss: 0.0264 - val_angular_mae_minutes: 9.7203 - val_loss: 0.0144 - learning_rate: 7.8125e-06
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.3501 - loss: 0.0256 - val_angular_mae_minutes: 7.8678 - val_loss: 0.0097 - learning_rate: 7.8125e-06
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - angular_mae_minutes: 14.6298 - loss: 0.0266 - val_angular_mae_minutes: 11.7762 - val_loss: 0.0254 - learning_rate: 7.8125e-06

# %%
best = keras.models.load_model(
    "best_model.keras",
    custom_objects={
        "CosSin": CosSin,
        "angular_mse": angular_mse,
        "angular_mae_minutes": angular_mae_minutes
    }
)

# Valutiamo sul test set
test_loss, test_acc = best.evaluate(X_train, y_train)
print(f"Loss sul train set: {test_loss:.4f}")
print(f"Accuratezza sul train set: {test_acc:.4f}")

# Valutiamo sul test set
test_loss, test_acc = best.evaluate(X_test, y_test)
print(f"Loss sul test set: {test_loss:.4f}")
print(f"Accuratezza sul test set: {test_acc:.4f}")
# Out:
# 2025-10-26 10:33:27.781647: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-10-26 10:33:28.075160: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_238', 100 bytes spill stores, 100 bytes spill loads
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - angular_mae_minutes: 6.4712 - loss: 0.0057
# Loss sul train set: 0.0057
# Accuratezza sul train set: 6.4712
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - angular_mae_minutes: 8.0832 - loss: 0.0095
# Loss sul test set: 0.0095
# Accuratezza sul test set: 8.0832

# %%
y_pred = model_base.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

"""from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_classes)
ConfusionMatrixDisplay(cm).plot()
"""
# Out:
#  1/57 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 'from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay\n\ncm = confusion_matrix(y_test, y_pred_classes)\nConfusionMatrixDisplay(cm).plot()\n'

# %%
plt.figure(figsize=(12,5))

# Angular MAE (in minuti)
plt.subplot(1,2,1)
plt.plot(history_base.history["angular_mae_minutes"], label="Train")
plt.plot(history_base.history["val_angular_mae_minutes"], label="Validation")
plt.title("mae (minutes)")
plt.xlabel("Epoch")
plt.ylabel("MAE (minutes)")
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history_base.history["loss"], label="Train")
plt.plot(history_base.history["val_loss"], label="Validation")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()
